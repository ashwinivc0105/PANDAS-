# %% [markdown]
# ##### step 1. load the iris.csv dataset.

# %%
import pandas as pd
import numpy as np
iris=pd.read_csv(r"C:\Users\DELL\Untitled Folder\IBM_Python_exercises\Iris.csv")
iris.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %% [markdown]
# ##### 1. Write a Pandas program to get the data types of the given csv data (iris.csv ) fields

# %%
### code here
iris.dtypes
# Out:
# Id                 int64
# SepalLengthCm    float64
# SepalWidthCm     float64
# PetalLengthCm    float64
# PetalWidthCm     float64
# Species           object
# dtype: object

# %% [markdown]
# ##### 2. Write a Pandas program to find the sum, mean, max, min value of 'SepalLengthCm' column of dataframe

# %%
### code here
print('Sum of SepalLengthCm Column:', iris['SepalLengthCm'].sum())
print('mean of SepalLengthCm Column:', iris['SepalLengthCm'].mean())
print('Max of SepalLengthCm Column:', iris['SepalLengthCm'].max())
print('Min of SepalLengthCm Column:', iris['SepalLengthCm'].min())
# Out:
# Sum of SepalLengthCm Column: 876.5
# mean of SepalLengthCm Column: 5.843333333333335
# Max of SepalLengthCm Column: 7.9
# Min of SepalLengthCm Column: 4.3

# %% [markdown]
# ##### 3. Write a Pandas program to import iris data and skipping first twenty rows into a Pandas dataframe.

# %%
### code here
skip_iris=pd.read_csv(r"C:\Users\DELL\Untitled Folder\IBM_Python_exercises\Iris.csv",skiprows=range(20))
skip_iris
# Out:
#       20  5.1  3.8  1.5  0.3     Iris-setosa
# 0     21  5.4  3.4  1.7  0.2     Iris-setosa
# 1     22  5.1  3.7  1.5  0.4     Iris-setosa
# 2     23  4.6  3.6  1.0  0.2     Iris-setosa
# 3     24  5.1  3.3  1.7  0.5     Iris-setosa
# 4     25  4.8  3.4  1.9  0.2     Iris-setosa
# ..   ...  ...  ...  ...  ...             ...
# 125  146  6.7  3.0  5.2  2.3  Iris-virginica
# 126  147  6.3  2.5  5.0  1.9  Iris-virginica
# 127  148  6.5  3.0  5.2  2.0  Iris-virginica
# 128  149  6.2  3.4  5.4  2.3  Iris-virginica
# 129  150  5.9  3.0  5.1  1.8  Iris-virginica
#
# [130 rows x 6 columns]

# %% [markdown]
# ##### 4. Write a Pandas program to display the last ten rows.

# %%
### code here
iris.tail(10)
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 140  141            6.7           3.1            5.6           2.4
# 141  142            6.9           3.1            5.1           2.3
# 142  143            5.8           2.7            5.1           1.9
# 143  144            6.8           3.2            5.9           2.3
# 144  145            6.7           3.3            5.7           2.5
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 140  Iris-virginica
# 141  Iris-virginica
# 142  Iris-virginica
# 143  Iris-virginica
# 144  Iris-virginica
# 145  Iris-virginica
# 146  Iris-virginica
# 147  Iris-virginica
# 148  Iris-virginica
# 149  Iris-virginica

# %% [markdown]
# ##### 5. Write a Pandas program to create a subtotal of "PetalLengthCm" against Species from the dataframe.

# %%
### code here
iris.groupby('Species')['PetalLengthCm'].sum()
# Out:
# Species
# Iris-setosa         73.2
# Iris-versicolor    213.0
# Iris-virginica     277.6
# Name: PetalLengthCm, dtype: float64

# %%
#iris[['Species','PetalLengthCm']].groupby('Species').sum()

# %% [markdown]
# ###### 6. Write a Pandas program to find details where "PetalLengthCm" > 2.

# %%
### code here
iris[iris["PetalLengthCm"]> 2]
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 50    51            7.0           3.2            4.7           1.4
# 51    52            6.4           3.2            4.5           1.5
# 52    53            6.9           3.1            4.9           1.5
# 53    54            5.5           2.3            4.0           1.3
# 54    55            6.5           2.8            4.6           1.5
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#              Species
# 50   Iris-versicolor
# 51   Iris-versicolor
# 52   Iris-versicolor
# 53   Iris-versicolor
# 54   Iris-versicolor
# ..               ...
# 145   Iris-virginica
# 146   Iris-virginica
# 147   Iris-virginica
# 148   Iris-virginica
# 149   Iris-virginica
#
# [100 rows x 6 columns]

# %% [markdown]
# ###### 7. Write a Pandas program find all records that include two specific Species.

# %%
### code here
specific_species = ['Iris-setosa', 'Iris-versicolor']
iris[iris['Species'].isin(specific_species)]
# Out:
#      Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0     1            5.1           3.5            1.4           0.2
# 1     2            4.9           3.0            1.4           0.2
# 2     3            4.7           3.2            1.3           0.2
# 3     4            4.6           3.1            1.5           0.2
# 4     5            5.0           3.6            1.4           0.2
# ..  ...            ...           ...            ...           ...
# 95   96            5.7           3.0            4.2           1.2
# 96   97            5.7           2.9            4.2           1.3
# 97   98            6.2           2.9            4.3           1.3
# 98   99            5.1           2.5            3.0           1.1
# 99  100            5.7           2.8            4.1           1.3
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# 95  Iris-versicolor
# 96  Iris-versicolor
# 97  Iris-versicolor
# 98  Iris-versicolor
# 99  Iris-versicolor
#
# [100 rows x 6 columns]

# %% [markdown]
# ###### 8.  Write a Pandas program to sort the records by the SepalLengthCm column.

# %%
### code here
di.sort_values('SepalLengthCm')
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 13    14            4.3           3.0            1.1           0.1
# 42    43            4.4           3.2            1.3           0.2
# 38    39            4.4           3.0            1.3           0.2
# 8      9            4.4           2.9            1.4           0.2
# 41    42            4.5           2.3            1.3           0.3
# ..   ...            ...           ...            ...           ...
# 122  123            7.7           2.8            6.7           2.0
# 118  119            7.7           2.6            6.9           2.3
# 117  118            7.7           3.8            6.7           2.2
# 135  136            7.7           3.0            6.1           2.3
# 131  132            7.9           3.8            6.4           2.0
#
#             Species
# 13      Iris-setosa
# 42      Iris-setosa
# 38      Iris-setosa
# 8       Iris-setosa
# 41      Iris-setosa
# ..              ...
# 122  Iris-virginica
# 118  Iris-virginica
# 117  Iris-virginica
# 135  Iris-virginica
# 131  Iris-virginica
#
# [150 rows x 6 columns]

# %% [markdown]
# ##### 9. Write a Pandas program to insert a column in the sixth position of dataframe and fill it with NaN values.

# %%
### code here
di['NEW_COL']=np.NaN
di
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species  NEW_COL
# 0       Iris-setosa      NaN
# 1       Iris-setosa      NaN
# 2       Iris-setosa      NaN
# 3       Iris-setosa      NaN
# 4       Iris-setosa      NaN
# ..              ...      ...
# 145  Iris-virginica      NaN
# 146  Iris-virginica      NaN
# 147  Iris-virginica      NaN
# 148  Iris-virginica      NaN
# 149  Iris-virginica      NaN
#
# [150 rows x 7 columns]

# %% [markdown]
# ##### 10. Write a Pandas program to add summation to a row of the dataframe.

# %%
### code here 
iris.sum(axis=1)
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_15356\880048241.py:2: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   p=iris.sum(axis=1)
# 0         11.2
# 1         11.5
# 2         12.4
# 3         13.4
# 4         15.2
#         ...
# 147      164.7
# 148      166.3
# 149      165.8
# sum    13403.2
# Sum    26806.4
# Length: 152, dtype: float64
